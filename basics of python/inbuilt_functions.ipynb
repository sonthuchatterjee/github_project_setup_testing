# %%
a=[1,2,'33']
print(a)
print(type(a))
print(dir(a))

b="hello python"
print(dir(b))
# Out:
# [1, 2, '33']
# <class 'list'>
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
# ...

# %%
a=["Hello","How","Are","doing"]
print(sorted(a,reverse=True))
print(sorted(a,key = lambda x: len(x),reverse=True))
# Out:
# ['doing', 'How', 'Hello', 'Are']
# ['Hello', 'doing', 'How', 'Are']

# %%
print(type(range(2)))
print(type(list(range(2))))
# Out:
# <class 'range'>
# <class 'list'>

# %%
a=[2,3,4]
b=(1,2,'3','67',a)
print(b,type(b))
print(b[4])
b[4] = 45
# Out:
# (1, 2, '3', '67', [2, 3, 4]) <class 'tuple'>
# [2, 3, 4]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       3 print(b,type(b))
#       4 print(b[4])
# ----> 5 b[4] = 45
#
# TypeError: 'tuple' object does not support item assignment

# %%
dic = {'1':3,'2':3,'2':3}
print(dic.items())
print(len(dic))

dic = {'1':3,'2':3,'3':3}
print(dic.items())
print(len(dic))
# Out:
# dict_items([('1', 3), ('2', 3)])
# 2
# dict_items([('1', 3), ('2', 3), ('3', 3)])
# 3

# %%
from collections import Counter

a = Counter(['a','a','b','b'])
print(a)

b= Counter({'a':1,'b':23})
b['b']+=1
b['a']+=2
print(b)
# Out:
# Counter({'a': 2, 'b': 2})
# Counter({'b': 24, 'a': 3})

# %%
from queue import Queue
Q=Queue(maxsize=2)
Q.put('wash the hand')
Q.put("eat the dinner")
print(Q.qsize())
#Q.put("Eat the deset")
print(Q.get())
Q.task_done()
print(Q.get())
print(Q.qsize())
Q.put("now what to do")
print(Q.qsize())
# Out:
# 2
# wash the hand
# eat the dinner
# 0
# 1

# %%
from collections import deque
from collections import namedtuple
user = namedtuple('User','name,age,classes')

sonthu = user(name="sonthu",age = "34",classes = 2012)
print(sonthu[:2])

monu = user(name = "monu",age ='',classes ='' )
print(monu[:2])

sonu = user(name = "sonu")
print(sonu[:2])
# Out:
# ('sonthu', '34')
# ('monu', '')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       8 monu = user(name = "monu",age ='',classes ='' )
#       9 print(monu[:2])
# ---> 11 sonu = user(name = "sonu")
#      12 print(sonu[:2])
#
# TypeError: User.__new__() missing 2 required positional arguments: 'age' and 'classes'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
a = ('1','2','3','4')
b = ('a','b','c','d')

lis = list(zip(a,b))
print(lis)
print(list(zip(*lis)))
# Out:
# [('1', 'a'), ('2', 'b'), ('3', 'c'), ('4', 'd')]
# [('1', '2', '3', '4'), ('a', 'b', 'c', 'd')]

# %%
a = (1,2,3,4)
b = ('a','b','c','d')

print(list(map(lambda x:x.upper(),b)))
print(list(filter(lambda x: x >2,a)))
# Out:
# ['A', 'B', 'C', 'D']
# [3, 4]
